# %% [markdown]
# # ΔΗΜΟΚΡΙΤΕΙΟ ΠΑΝΕΠΙΣΤΗΜΙΟ ΘΡΑΚΗΣ

# %%
# Αρχικοποίηση προγράμματος
import requests
import xml.etree.ElementTree as ET
import matplotlib.pyplot as plt # Προσθήκη για γραφήματα
import matplotlib.ticker as ticker # Για καλύτερη μορφοποίηση των αξόνων

# UID για ΔΠΘ
uid = "99202868"

# URL για XML πληροφορίες οργανισμού
url = f"https://diavgeia.gov.gr/opendata/organizations/{uid}.xml"
base_url = "https://diavgeia.gov.gr/opendata/search.json"

# Χρόνικό όριο αναζήτησης
years_range = range(2019, 2025)

# %% [markdown]
# ## Ερώτημα 1
#
# ### Ανάκτηση στοιχείων του ιδρύματος

# %%
# Ερώτημα 1

# Κάνουμε το αίτημα
response = requests.get(url)
xml_data = response.content

# Παράμετροι για XML parsing
namespace = {'ns': 'http://diavgeia.gov.gr/schema/v2'}
root = ET.fromstring(xml_data)

# Εξαγωγή δεδομένων
label = root.find('ns:label', namespace).text
latin_name = root.find('ns:latinName', namespace).text
status = root.find('ns:status', namespace).text
category = root.find('ns:category', namespace).text
vat = root.find('ns:vatNumber', namespace).text
website = root.find('ns:website', namespace).text
supervisor = root.find('ns:supervisorLabel', namespace).text

# Εμφάνιση αποτελεσμάτων
print(f"Ονομασία: {label}")
print(f"Λατινικό Όνομα: {latin_name}")
print(f"Κατάσταση: {status}")
print(f"Κατηγορία: {category}")
print(f"ΑΦΜ: {vat}")
print(f"Ιστοσελίδα: {website}")
print(f"Εποπτεύουσα Αρχή: {supervisor}")
# Out:
# Ονομασία: ΔΗΜΟΚΡΙΤΕΙΟ ΠΑΝΕΠΙΣΤΗΜΙΟ ΘΡΑΚΗΣ
# Λατινικό Όνομα: duth
# Κατάσταση: active
# Κατηγορία: UNIVERSITY
# ΑΦΜ: 090028889
# Ιστοσελίδα: http://www.duth.gr
# Εποπτεύουσα Αρχή: ΥΠΟΥΡΓΕΙΟ ΠΑΙΔΕΙΑΣ, ΘΡΗΣΚΕΥΜΑΤΩΝ ΚΑΙ ΑΘΛΗΤΙΣΜΟΥ

# %% [markdown]
# ## Ερώτημα 2
#
# ### Αναρτήσεις πράξεων έχει προχωρήσει κάθε Ίδρυμα με ημερομηνία έκδοσης (issue date) κατά τα έτη 2019-2024

# %%
# Ερώτημα 2
results_q2 = {} # Αρχικοποίηση του λεξικού για τα αποτελέσματα του Ερωτήματος 2
print(f"🔍 Αναζήτηση συνολικών πράξεων για τον οργανισμό ΔΠΘ (UID: {uid})...\n")

for year_val in years_range:
    print(f"  🔄 Επεξεργασία έτους: {year_val}...")
    yearly_total_for_this_year = 0
    error_occurred_this_year = False

    # Καθορισμός των τριών τετραμηνιαίων περιόδων για το τρέχον έτος
    # Περίοδος 1: Μήνες 1-4
    # Περίοδος 2: Μήνες 5-8
    # Περίοδος 3: Μήνες 9-12
    date_periods_q2 = [
        (f"{year_val}-01-01", f"{year_val}-04-30", "1ο τετράμηνο"),
        (f"{year_val}-05-01", f"{year_val}-08-31", "2ο τετράμηνο"),
        (f"{year_val}-09-01", f"{year_val}-12-31", "3ο τετράμηνο")
    ]

    for from_date, to_date, period_label in date_periods_q2:
        # Μήνυμα για κάθε τετράμηνο (προαιρετικό)
        # print(f"    -> Αναζήτηση για {period_label} ({from_date} έως {to_date})...")
        params = {
            "org": uid,
            "from_issue_date": from_date,
            "to_issue_date": to_date,
            "size": 1
        }

        try:
            response = requests.get(base_url, params=params, timeout=45)
            response.raise_for_status()
            data = response.json()

            # Έλεγχος αν υπάρχουν αποτελέσματα
            sub_total = data.get("info", {}).get("total", 0)
            yearly_total_for_this_year += sub_total
            # Αποτέλεσμα του τετραμήνου (προαιρετικό)
            # print(f"    ✅ {period_label}: {sub_total} πράξεις βρέθηκαν.")

        except requests.exceptions.HTTPError as http_err:
            print(f"    ⚠️  Σφάλμα HTTP για {period_label} έτους {year_val}. Η επεξεργασία του έτους θα διακοπεί. Σφάλμα: {http_err}")
            error_occurred_this_year = True
            break
        except requests.exceptions.RequestException as req_err:
            print(f"    ⚠️  Σφάλμα αιτήματος για {period_label} έτους {year_val}. Η επεξεργασία του έτους θα διακοπεί. Σφάλμα: {req_err}")
            error_occurred_this_year = True
            break
        except ValueError as json_err:
            print(f"    ⚠️  Σφάλμα JSON για {period_label} έτους {year_val}. Η επεξεργασία του έτους θα διακοπεί. Σφάλμα: {json_err} (Απάντηση: {response.text[:100]})")
            error_occurred_this_year = True
            break
        except Exception as e:
            print(f"    ⚠️  Άγνωστο σφάλμα για {period_label} έτους {year_val}. Η επεξεργασία του έτους θα διακοπεί. Σφάλμα: {e}")
            error_occurred_this_year = True
            break

    if error_occurred_this_year:
        results_q2[year_val] = "Σφάλμα/Ελλιπή" # Χρησιμοποιούμε string για να είναι σαφές στον πίνακα
        print(f"  ❌ Ολοκληρώθηκε με σφάλματα η επεξεργασία του έτους {year_val}.\n")
    else:
        results_q2[year_val] = yearly_total_for_this_year
        print(f"  ✅ Ολοκληρώθηκε η επεξεργασία του έτους {year_val}. Σύνολο: {yearly_total_for_this_year}\n")

# Εμφάνιση αποτελεσμάτων σε πίνακα
print("\n" + "="*40)
print(f"📊 Σύνολο Πράξεων ανά Έτος")
print(f"   Οργανισμός ΔΠΘ (UID: {uid})")
print("="*40)
print(f"{'Έτος':<6} | {'Πλήθος Πράξεων':<20}")
print("-"*40)
for year_key, count_val in results_q2.items():
    # Εμφάνιση του 'Σφάλμα/Ελλιπή' ή του αριθμού
    display_count = count_val if isinstance(count_val, int) else str(count_val)
    print(f"{year_key:<6} | {display_count:<20}")
print("="*40 + "\n")


# ------- Προσθήκη Ραβδογράμματος  -------
plot_years_list_q2 = []
plot_counts_list_q2 = []

for year_item, count_item in results_q2.items():
    if isinstance(count_item, int): # Συμπεριλαμβάνουμε μόνο έτη χωρίς σφάλματα (δηλαδή με ακέραιο πλήθος)
        plot_years_list_q2.append(str(year_item))
        plot_counts_list_q2.append(count_item)
    else:
        print(f"ℹ️ Το έτος {year_item} παραλείπεται από το γράφημα λόγω σφάλματος/ελλιπών δεδομένων.")


if plot_years_list_q2 and plot_counts_list_q2:
    plt.figure(figsize=(10, 6))
    bars = plt.bar(plot_years_list_q2, plot_counts_list_q2, color='blue')

    plt.title(f'Πλήθος Αναρτημένων Πράξεων ανά Έτος\nΔΗΜΟΚΡΙΤΕΙΟ ΠΑΝΕΠΙΣΤΗΜΙΟ ΘΡΑΚΗΣ (UID: {uid})', fontsize=14)
    plt.xlabel('Έτος', fontsize=12)
    plt.ylabel('Πλήθος Πράξεων', fontsize=12)
    plt.xticks(rotation=45, ha="right")
    plt.yticks(fontsize=10)
    plt.grid(axis='y', linestyle='--', alpha=0.7)

    ax = plt.gca()
    ax.yaxis.set_major_locator(ticker.MaxNLocator(integer=True))

    for bar in bars:
        yval = bar.get_height()
        max_val_for_text_offset = max(plot_counts_list_q2) if plot_counts_list_q2 else 1
        if max_val_for_text_offset == 0 : max_val_for_text_offset = 1

        if yval > 0: # Εμφανίζουμε τιμή μόνο αν είναι > 0
             plt.text(bar.get_x() + bar.get_width()/2.0, yval + 0.01 * max_val_for_text_offset,
                     f'{int(yval)}', ha='center', va='bottom', fontsize=9)
        

    plt.tight_layout()

    graph_filename_total_q2 = f"praxeis_synolikes_q2_{uid}.png"
    plt.savefig(graph_filename_total_q2)
    print(f"\n📈 Το γράφημα των συνολικών πράξεων (Ερώτημα 2) αποθηκεύτηκε ως '{graph_filename_total_q2}'")
else:
    print("\n🚫 Δεν υπάρχουν επαρκή δεδομένα (χωρίς σφάλματα) για τη δημιουργία γραφήματος συνολικών πράξεων (Ερώτημα 2).")
# Out:
# 🔍 [Ερώτημα 2] Αναζήτηση συνολικών πράξεων για τον οργανισμό ΔΠΘ (UID: 99202868)...
#
#   🔄 Επεξεργασία έτους: 2019...
#   ✅ Ολοκληρώθηκε η επεξεργασία του έτους 2019. Σύνολο: 31236
#
#   🔄 Επεξεργασία έτους: 2020...
#   ✅ Ολοκληρώθηκε η επεξεργασία του έτους 2020. Σύνολο: 27084
#
#   🔄 Επεξεργασία έτους: 2021...
#   ✅ Ολοκληρώθηκε η επεξεργασία του έτους 2021. Σύνολο: 30379
#
#   🔄 Επεξεργασία έτους: 2022...
#   ✅ Ολοκληρώθηκε η επεξεργασία του έτους 2022. Σύνολο: 36038
#
#   🔄 Επεξεργασία έτους: 2023...
#   ✅ Ολοκληρώθηκε η επεξεργασία του έτους 2023. Σύνολο: 34216
#
#   🔄 Επεξεργασία έτους: 2024...
#   ✅ Ολοκληρώθηκε η επεξεργασία του έτους 2024. Σύνολο: 31059
#
#
# ========================================
# 📊 Σύνολο Πράξεων ανά Έτος
#    Οργανισμός ΔΠΘ (UID: 99202868)
# ========================================
# Έτος   | Πλήθος Πράξεων
# ----------------------------------------
# 2019   | 31236
# 2020   | 27084
# 2021   | 30379
# 2022   | 36038
# 2023   | 34216
# 2024   | 31059
# ========================================
#
#
# 📈 Το γράφημα των συνολικών πράξεων (Ερώτημα 2) αποθηκεύτηκε ως 'praxeis_synolikes_q2_99202868.png'

# %% [markdown]
# ## Ερώτημα 3
#
# ### Πόσες από τις πράξεις αυτές έχουν ανακληθεί (ανά έτος);

# %%
# Ερώτημα 3

results_q3 = {} # Αρχικοποίηση του λεξικού για τα αποτελέσματα του Ερωτήματος 3
# ----------------------------------------------------------

print(f"🔍 Αναζήτηση ΑΝΑΚΛΗΜΕΝΩΝ πράξεων για τον οργανισμό ΔΠΘ (UID: {uid})...\n")

for year_val in years_range:
    print(f"  🔄 Επεξεργασία έτους: {year_val} για ανακλημένες πράξεις...")
    yearly_total_revoked_this_year = 0
    error_occurred_this_year_q3 = False

    date_periods_q3 = [
        (f"{year_val}-01-01", f"{year_val}-04-30", "1ο τετράμηνο"),
        (f"{year_val}-05-01", f"{year_val}-08-31", "2ο τετράμηνο"),
        (f"{year_val}-09-01", f"{year_val}-12-31", "3ο τετράμηνο")
    ]

    for from_date, to_date, period_label in date_periods_q3:
        params = {
            "org": uid,
            "from_issue_date": from_date,
            "to_issue_date": to_date,
            "status": "revoked",  # <--- ΚΡΙΣΙΜΗ ΠΑΡΑΜΕΤΡΟΣ ΓΙΑ ΤΟ ΕΡΩΤΗΜΑ 3
            "size": 1
        }

        try:
            response = requests.get(base_url, params=params, timeout=45)
            response.raise_for_status()
            data = response.json()

            # Εδώ ελέγχουμε αν η απάντηση είναι κενή
            sub_total_revoked = data.get("info", {}).get("total", 0)
            yearly_total_revoked_this_year += sub_total_revoked

        except requests.exceptions.HTTPError as http_err:
            print(f"    ⚠️  Σφάλμα HTTP για {period_label} έτους {year_val} (ανακλημένες). Διακοπή για το έτος. Σφάλμα: {http_err}")
            error_occurred_this_year_q3 = True
            break
        except requests.exceptions.RequestException as req_err:
            print(f"    ⚠️  Σφάλμα αιτήματος για {period_label} έτους {year_val} (ανακλημένες). Διακοπή για το έτος. Σφάλμα: {req_err}")
            error_occurred_this_year_q3 = True
            break
        except ValueError as json_err:
            print(f"    ⚠️  Σφάλμα JSON για {period_label} έτους {year_val} (ανακλημένες). Διακοπή για το έτος. Σφάλμα: {json_err} (Απάντηση: {response.text[:100]})")
            error_occurred_this_year_q3 = True
            break
        except Exception as e:
            print(f"    ⚠️  Άγνωστο σφάλμα για {period_label} έτους {year_val} (ανακλημένες). Διακοπή για το έτος. Σφάλμα: {e}")
            error_occurred_this_year_q3 = True
            break

    if error_occurred_this_year_q3:
        results_q3[year_val] = "Σφάλμα/Ελλιπή"
        print(f"  ❌ Ολοκληρώθηκε με σφάλματα η επεξεργασία του έτους {year_val} για ανακλημένες πράξεις.\n")
    else:
        results_q3[year_val] = yearly_total_revoked_this_year
        print(f"  ✅ Ολοκληρώθηκε η επεξεργασία του έτους {year_val} για ανακλημένες πράξεις. Σύνολο: {yearly_total_revoked_this_year}\n")

# Εμφάνιση αποτελεσμάτων για τις ανακλημένες πράξεις σε πίνακα
print("\n" + "="*50)
print(f"📊 Πλήθος ΑΝΑΚΛΗΜΕΝΩΝ Πράξεων ανά Έτος")
print(f"   Οργανισμός ΔΠΘ (UID: {uid})")
print("="*50)
print(f"{'Έτος':<6} | {'Πλήθος Ανακλημένων Πράξεων':<30}")
print("-"*50)
for year_key, count_val in results_q3.items():
    display_count_q3 = count_val if isinstance(count_val, int) else str(count_val)
    print(f"{year_key:<6} | {display_count_q3:<30}")
print("="*50 + "\n")

# ------- Προσθήκη Γραφήματος για τις ΑΝΑΚΛΗΜΕΝΕΣ πράξεις -------
plot_revoked_years_list_q3 = []
plot_revoked_counts_list_q3 = []

for year_item, count_item in results_q3.items():
    if isinstance(count_item, int):
        plot_revoked_years_list_q3.append(str(year_item))
        plot_revoked_counts_list_q3.append(count_item)
    else:
        print(f"ℹ️ [Ερώτημα 3] Το έτος {year_item} παραλείπεται από το γράφημα ανακλημένων πράξεων λόγω σφάλματος/ελλιπών δεδομένων.")


if plot_revoked_years_list_q3 and plot_revoked_counts_list_q3:
    plt.figure(figsize=(10, 6))
    bars_q3 = plt.bar(plot_revoked_years_list_q3, plot_revoked_counts_list_q3, color='coral')

    plt.title(f'Πλήθος Ανακλημένων Πράξεων ανά Έτος\nΔΗΜΟΚΡΙΤΕΙΟ ΠΑΝΕΠΙΣΤΗΜΙΟ ΘΡΑΚΗΣ (UID: {uid})', fontsize=14)
    plt.xlabel('Έτος', fontsize=12)
    plt.ylabel('Πλήθος Ανακλημένων Πράξεων', fontsize=12)
    plt.xticks(rotation=45, ha="right")
    plt.yticks(fontsize=10)
    plt.grid(axis='y', linestyle='--', alpha=0.7)

    ax_q3 = plt.gca()
    ax_q3.yaxis.set_major_locator(ticker.MaxNLocator(integer=True))

    for bar in bars_q3:
        yval = bar.get_height()
        max_val_for_text_offset_q3 = max(plot_revoked_counts_list_q3) if plot_revoked_counts_list_q3 else 1
        if max_val_for_text_offset_q3 == 0 : max_val_for_text_offset_q3 = 1

        if yval > 0:
             plt.text(bar.get_x() + bar.get_width()/2.0, yval + 0.01 * max_val_for_text_offset_q3,
                     f'{int(yval)}', ha='center', va='bottom', fontsize=9)


    plt.tight_layout()
    graph_filename_revoked_q3 = f"praxeis_anaklimenes_q3_{uid}.png"
    plt.savefig(graph_filename_revoked_q3)
    print(f"\n📈 Το γράφημα των ανακλημένων πράξεων (Ερώτημα 3) αποθηκεύτηκε ως '{graph_filename_revoked_q3}'")
else:
    print("\n🚫 Δεν υπάρχουν επαρκή δεδομένα (χωρίς σφάλματα) για τη δημιουργία γραφήματος ανακλημένων πράξεων (Ερώτημα 3).")
# Out:
# 🔍 Αναζήτηση ΑΝΑΚΛΗΜΕΝΩΝ πράξεων για τον οργανισμό ΔΠΘ (UID: 99202868)...
#
#   🔄 Επεξεργασία έτους: 2019 για ανακλημένες πράξεις...
#   ✅ Ολοκληρώθηκε η επεξεργασία του έτους 2019 για ανακλημένες πράξεις. Σύνολο: 3
#
#   🔄 Επεξεργασία έτους: 2020 για ανακλημένες πράξεις...
#   ✅ Ολοκληρώθηκε η επεξεργασία του έτους 2020 για ανακλημένες πράξεις. Σύνολο: 12
#
#   🔄 Επεξεργασία έτους: 2021 για ανακλημένες πράξεις...
#   ✅ Ολοκληρώθηκε η επεξεργασία του έτους 2021 για ανακλημένες πράξεις. Σύνολο: 2
#
#   🔄 Επεξεργασία έτους: 2022 για ανακλημένες πράξεις...
#   ✅ Ολοκληρώθηκε η επεξεργασία του έτους 2022 για ανακλημένες πράξεις. Σύνολο: 4
#
#   🔄 Επεξεργασία έτους: 2023 για ανακλημένες πράξεις...
#   ✅ Ολοκληρώθηκε η επεξεργασία του έτους 2023 για ανακλημένες πράξεις. Σύνολο: 1
#
#   🔄 Επεξεργασία έτους: 2024 για ανακλημένες πράξεις...
#   ✅ Ολοκληρώθηκε η επεξεργασία του έτους 2024 για ανακλημένες πράξεις. Σύνολο: 2
#
#
# ==================================================
# 📊 Πλήθος ΑΝΑΚΛΗΜΕΝΩΝ Πράξεων ανά Έτος
#    Οργανισμός ΔΠΘ (UID: 99202868)
# ==================================================
# Έτος   | Πλήθος Ανακλημένων Πράξεων
# --------------------------------------------------
# 2019   | 3
# 2020   | 12
# 2021   | 2
# 2022   | 4
# 2023   | 1
# 2024   | 2
# ==================================================
#
#
# 📈 Το γράφημα των ανακλημένων πράξεων (Ερώτημα 3) αποθηκεύτηκε ως 'praxeis_anaklimenes_q3_99202868.png'

# %% [markdown]
# ## Ερώτημα 4
#
# ### Πόσες από τις πράξεις που έχουν ανακληθεί περιέχουν προσωπικά δεδομένα;

# %%
# Ερώτημα 4


results_q4 = {} # Αρχικοποίηση του λεξικού για τα αποτελέσματα του Ερωτήματος 4
# ----------------------------------------------------------

print(f"🔍 [Ερώτημα 4] Αναζήτηση ΑΝΑΚΛΗΜΕΝΩΝ πράξεων ΜΕ ΠΡΟΣΩΠΙΚΑ ΔΕΔΟΜΕΝΑ για τον οργανισμό ΔΠΘ (UID: {uid})...\n")

for year_val in years_range:
    print(f"  🔄 Επεξεργασία έτους: {year_val} για ανακλημένες πράξεις με προσωπικά δεδομένα...")
    yearly_total_revoked_pd_this_year = 0 # pd = personal data
    error_occurred_this_year_q4 = False

    date_periods_q4 = [
        (f"{year_val}-01-01", f"{year_val}-04-30", "1ο τετράμηνο"),
        (f"{year_val}-05-01", f"{year_val}-08-31", "2ο τετράμηνο"),
        (f"{year_val}-09-01", f"{year_val}-12-31", "3ο τετράμηνο")
    ]

    for from_date, to_date, period_label in date_periods_q4:
        params = {
            "org": uid,
            "from_issue_date": from_date,
            "to_issue_date": to_date,
            "status": "revoked",
            "privateData": "true",  # <--- ΠΡΟΣΘΗΚΗ ΓΙΑ ΤΟ ΕΡΩΤΗΜΑ 4
            "size": 1
        }

        try:
            response = requests.get(base_url, params=params, timeout=45)
            response.raise_for_status()
            data = response.json()

            # Εδώ ελέγχουμε αν η απάντηση είναι κενή
            sub_total_revoked_pd = data.get("info", {}).get("total", 0)
            yearly_total_revoked_pd_this_year += sub_total_revoked_pd

        except requests.exceptions.HTTPError as http_err:
            print(f"    ⚠️  Σφάλμα HTTP για {period_label} έτους {year_val} (ανακλ. με προσ. δεδ.). Διακοπή για το έτος. Σφάλμα: {http_err}")
            error_occurred_this_year_q4 = True
            break
        except requests.exceptions.RequestException as req_err:
            print(f"    ⚠️  Σφάλμα αιτήματος για {period_label} έτους {year_val} (ανακλ. με προσ. δεδ.). Διακοπή για το έτος. Σφάλμα: {req_err}")
            error_occurred_this_year_q4 = True
            break
        except ValueError as json_err:
            print(f"    ⚠️  Σφάλμα JSON για {period_label} έτους {year_val} (ανακλ. με προσ. δεδ.). Διακοπή για το έτος. Σφάλμα: {json_err} (Απάντηση: {response.text[:100]})")
            error_occurred_this_year_q4 = True
            break
        except Exception as e:
            print(f"    ⚠️  Άγνωστο σφάλμα για {period_label} έτους {year_val} (ανακλ. με προσ. δεδ.). Διακοπή για το έτος. Σφάλμα: {e}")
            error_occurred_this_year_q4 = True
            break

    if error_occurred_this_year_q4:
        results_q4[year_val] = "Σφάλμα/Ελλιπή"
        print(f"  ❌ Ολοκληρώθηκε με σφάλματα η επεξεργασία του έτους {year_val} για ανακλημένες πράξεις με προσωπικά δεδομένα.\n")
    else:
        results_q4[year_val] = yearly_total_revoked_pd_this_year
        print(f"  ✅ Ολοκληρώθηκε η επεξεργασία του έτους {year_val} για ανακλημένες πράξεις με προσωπικά δεδομένα. Σύνολο: {yearly_total_revoked_pd_this_year}\n")

# Εμφάνιση αποτελεσμάτων για τις ανακλημένες πράξεις με προσωπικά δεδομένα σε πίνακα
print("\n" + "="*70)
print(f"📊 Πλήθος ΑΝΑΚΛΗΜΕΝΩΝ Πράξεων ΜΕ ΠΡΟΣΩΠΙΚΑ ΔΕΔΟΜΕΝΑ ανά Έτος")
print(f"   Οργανισμός ΔΠΘ (UID: {uid})")
print("="*70)
print(f"{'Έτος':<6} | {'Πλήθος Ανακλημένων Πράξεων με Προσωπικά Δεδομένα':<50}")
print("-"*70)
for year_key, count_val in results_q4.items():
    display_count_q4 = count_val if isinstance(count_val, int) else str(count_val)
    print(f"{year_key:<6} | {display_count_q4:<50}")
print("="*70 + "\n")

# ------- Προσθήκη Γραφήματος για τις ΑΝΑΚΛΗΜΕΝΕΣ πράξεις ΜΕ ΠΡΟΣΩΠΙΚΑ ΔΕΔΟΜΕΝΑ -------
plot_revoked_pd_years_list_q4 = []
plot_revoked_pd_counts_list_q4 = []

for year_item, count_item in results_q4.items():
    if isinstance(count_item, int):
        plot_revoked_pd_years_list_q4.append(str(year_item))
        plot_revoked_pd_counts_list_q4.append(count_item)
    else:
        print(f"ℹ️ [Ερώτημα 4] Το έτος {year_item} παραλείπεται από το γράφημα (ανακλ. με προσ. δεδομένα) λόγω σφάλματος/ελλιπών δεδομένων.")

if plot_revoked_pd_years_list_q4 and plot_revoked_pd_counts_list_q4:
    plt.figure(figsize=(10, 6))
    bars_q4 = plt.bar(plot_revoked_pd_years_list_q4, plot_revoked_pd_counts_list_q4, color='red')

    plt.title(f'Πλήθος Ανακλημένων Πράξεων με Προσωπικά Δεδομένα ανά Έτος\nΔΗΜΟΚΡΙΤΕΙΟ ΠΑΝΕΠΙΣΤΗΜΙΟ ΘΡΑΚΗΣ (UID: {uid})', fontsize=14)
    plt.xlabel('Έτος', fontsize=12)
    plt.ylabel('Πλήθος Ανακλημένων Πράξεων με Προσωπικά Δεδομένα', fontsize=10) # Μικρότερο μέγεθος για να χωράει καλύτερα
    plt.xticks(rotation=45, ha="right")
    plt.yticks(fontsize=10)
    plt.grid(axis='y', linestyle='--', alpha=0.7)

    ax_q4 = plt.gca()
    ax_q4.yaxis.set_major_locator(ticker.MaxNLocator(integer=True))

    for bar in bars_q4:
        yval = bar.get_height()
        max_val_for_text_offset_q4 = max(plot_revoked_pd_counts_list_q4) if plot_revoked_pd_counts_list_q4 else 1
        if max_val_for_text_offset_q4 == 0 : max_val_for_text_offset_q4 = 1

        if yval > 0:
             plt.text(bar.get_x() + bar.get_width()/2.0, yval + 0.01 * max_val_for_text_offset_q4,
                     f'{int(yval)}', ha='center', va='bottom', fontsize=9)

    plt.tight_layout()
    graph_filename_revoked_pd_q4 = f"praxeis_anaklimenes_proswpika_dedomena_q4_{uid}.png"
    plt.savefig(graph_filename_revoked_pd_q4)
    print(f"\n📈 Το γράφημα των ανακλημένων πράξεων με προσωπικά δεδομένα (Ερώτημα 4) αποθηκεύτηκε ως '{graph_filename_revoked_pd_q4}'")
else:
    print("\n🚫 Δεν υπάρχουν επαρκή δεδομένα (χωρίς σφάλματα) για τη δημιουργία γραφήματος ανακλημένων πράξεων με προσωπικά δεδομένα (Ερώτημα 4).")
# Out:
# 🔍 [Ερώτημα 4] Αναζήτηση ΑΝΑΚΛΗΜΕΝΩΝ πράξεων ΜΕ ΠΡΟΣΩΠΙΚΑ ΔΕΔΟΜΕΝΑ για τον οργανισμό ΔΠΘ (UID: 99202868)...
#
#   🔄 Επεξεργασία έτους: 2019 για ανακλημένες πράξεις με προσωπικά δεδομένα...
#   ✅ Ολοκληρώθηκε η επεξεργασία του έτους 2019 για ανακλημένες πράξεις με προσωπικά δεδομένα. Σύνολο: 3
#
#   🔄 Επεξεργασία έτους: 2020 για ανακλημένες πράξεις με προσωπικά δεδομένα...
#   ✅ Ολοκληρώθηκε η επεξεργασία του έτους 2020 για ανακλημένες πράξεις με προσωπικά δεδομένα. Σύνολο: 12
#
#   🔄 Επεξεργασία έτους: 2021 για ανακλημένες πράξεις με προσωπικά δεδομένα...
#   ✅ Ολοκληρώθηκε η επεξεργασία του έτους 2021 για ανακλημένες πράξεις με προσωπικά δεδομένα. Σύνολο: 2
#
#   🔄 Επεξεργασία έτους: 2022 για ανακλημένες πράξεις με προσωπικά δεδομένα...
#   ✅ Ολοκληρώθηκε η επεξεργασία του έτους 2022 για ανακλημένες πράξεις με προσωπικά δεδομένα. Σύνολο: 4
#
#   🔄 Επεξεργασία έτους: 2023 για ανακλημένες πράξεις με προσωπικά δεδομένα...
#   ✅ Ολοκληρώθηκε η επεξεργασία του έτους 2023 για ανακλημένες πράξεις με προσωπικά δεδομένα. Σύνολο: 1
#
#   🔄 Επεξεργασία έτους: 2024 για ανακλημένες πράξεις με προσωπικά δεδομένα...
#   ✅ Ολοκληρώθηκε η επεξεργασία του έτους 2024 για ανακλημένες πράξεις με προσωπικά δεδομένα. Σύνολο: 2
#
#
# ======================================================================
# 📊 Πλήθος ΑΝΑΚΛΗΜΕΝΩΝ Πράξεων ΜΕ ΠΡΟΣΩΠΙΚΑ ΔΕΔΟΜΕΝΑ ανά Έτος
#    Οργανισμός ΔΠΘ (UID: 99202868)
# ======================================================================
# Έτος   | Πλήθος Ανακλημένων Πράξεων με Προσωπικά Δεδομένα
# ----------------------------------------------------------------------
# 2019   | 3
# 2020   | 12
# 2021   | 2
# 2022   | 4
# 2023   | 1
# 2024   | 2
# ======================================================================
#
#
# 📈 Το γράφημα των ανακλημένων πράξεων με προσωπικά δεδομένα (Ερώτημα 4) αποθηκεύτηκε ως 'praxeis_anaklimenes_proswpika_dedomena_q4_99202868.png'

# %% [markdown]
# ## Ερώτημα 5
#
# ### Οργανωτικές μονάδες του ΔΠΘ.

# %%
# Ερώτημα 5

organization_name = "ΔΗΜΟΚΡΙΤΕΙΟ ΠΑΝΕΠΙΣΤΗΜΙΟ ΘΡΑΚΗΣ: {label}"

# Endpoint για τις οργανωτικές μονάδες ενός φορέα
units_url = f"https://diavgeia.gov.gr/opendata/organizations/{uid}/units.json"

active_organizational_units = []
total_units_count_from_api = 0
active_units_count = 0

print(f"🔍 Ανάκτηση ενεργών οργανωτικών μονάδων για {organization_name} (UID: {uid})...\n")

params = {
    "status": "active" # Ζητάμε απευθείας μόνο τις ενεργές
}

try:
    response = requests.get(units_url, params=params, timeout=30)
    response.raise_for_status() # Έλεγχος για HTTP errors

    data = response.json()
    units_data = data.get("units", []) # Η τεκμηρίωση δείχνει "units" ως το κύριο κλειδί

    if not units_data:
        print(f"ℹ️ Δεν βρέθηκαν οργανωτικές μονάδες για τον φορέα (βάσει API response).")
    else:
        # Το API επιστρέφει απευθείας τις ενεργές μονάδες με το status=active.
        # Επαληθεύουμε παρόλα αυτά αν υπάρχει το πεδίο "active": true για κάθε μονάδα
        for unit in units_data:
            if unit.get("active") is True: # Ρητός έλεγχος, αν και το API θα έπρεπε να επιστρέφει μόνο ενεργές
                active_organizational_units.append({
                    "uid": unit.get("uid"),
                    "label": unit.get("label"),
                    "category": unit.get("category") # Προσθήκη και κατηγορίας αν υπάρχει
                })
                active_units_count += 1

        # Το API δεν επιστρέφει 'info' block σε αυτό το endpoint για το συνολικό πλήθος,
        # οπότε ο αριθμός των εγγραφών στη λίστα 'units' είναι το σύνολο που λάβαμε.
        total_units_count_from_api = len(units_data)

        print(f"✅ Συνολικά ενεργές οργανωτικές μονάδες που ανακτήθηκαν: {active_units_count}")
        if total_units_count_from_api != active_units_count:
            print(f"   (Σημείωση: Το API επέστρεψε {total_units_count_from_api} μονάδες με status=active, όλες επαληθεύτηκαν ως ενεργές.)")


except requests.exceptions.HTTPError as http_err:
    print(f"❌ HTTP σφάλμα κατά την ανάκτηση οργανωτικών μονάδων: {http_err}")
except requests.exceptions.RequestException as req_err:
    print(f"❌ Σφάλμα αιτήματος κατά την ανάκτηση οργανωτικών μονάδων: {req_err}")
except ValueError as json_err:
    print(f"⚠️ Σφάλμα JSON κατά την ανάκτηση οργανωτικών μονάδων: {json_err} (Απάντηση: {response.text[:200]})")
except Exception as e:
    print(f"⚠️ Άγνωστο σφάλμα κατά την ανάκτηση οργανωτικών μονάδων: {e}")

# Εμφάνιση αποτελεσμάτων
print(f"\n🏢 Ενεργές Οργανωτικές Μονάδες για το {organization_name}:")
if active_organizational_units:
    print(f"Συνολικό Πλήθος Ενεργών Μονάδων: {active_units_count}")
    print("-" * 40)
    for i, unit in enumerate(active_organizational_units, 1):
        print(f"{i}. Ονομασία: {unit['label']} (UID: {unit['uid']})")
        if unit['category']:
             print(f"   Κατηγορία: {unit['category']}")
else:
    if active_units_count == 0 and total_units_count_from_api == 0 : #Μόνο αν δεν υπήρξε σφάλμα πιο πάνω
        print("Δεν βρέθηκαν ενεργές οργανωτικές μονάδες για αυτό το ΑΕΙ στη Δι@ύγεια.")
    elif active_units_count == 0 and total_units_count_from_api > 0 :
        print("Δεν βρέθηκαν μονάδες με 'active: true' στην απάντηση, αν και το API επέστρεψε μονάδες με status=active.")
    else: # Αν συνέβη κάποιο σφάλμα πιο πάνω
        print("Δεν ήταν δυνατή η ανάκτηση των οργανωτικών μονάδων.")
# Out:
# 🔍 Ανάκτηση ενεργών οργανωτικών μονάδων για ΔΗΜΟΚΡΙΤΕΙΟ ΠΑΝΕΠΙΣΤΗΜΙΟ ΘΡΑΚΗΣ: {label} (UID: 99202868)...
#
# ✅ Συνολικά ενεργές οργανωτικές μονάδες που ανακτήθηκαν: 133
#
# 🏢 Ενεργές Οργανωτικές Μονάδες για το ΔΗΜΟΚΡΙΤΕΙΟ ΠΑΝΕΠΙΣΤΗΜΙΟ ΘΡΑΚΗΣ: {label}:
# Συνολικό Πλήθος Ενεργών Μονάδων: 133
# ----------------------------------------
# 1. Ονομασία: ΑΙΣΘΗΤΗΡΙΩΝ ΟΡΓΑΝΩΝ & ΝΕΥΡΙΚΟΥ ΣΥΣΤΗΜΑΤΟΣ (UID: 100036756)
#    Κατηγορία: SECTOR
# 2. Ονομασία: ΒΙΒΛΙΟΘΗΚΗ Α ΝΟΜΙΚΗΣ, ΚΟΙΝΩΝΙΚΗΣ ΔΙΟΙΚΗΣΗΣ, ΔΙΕΘΝΩΝ ΟΙΚΟΝΟΜΙΚΩΝ ΣΧΕΣΕΩΝ ΚΑΙ ΑΝΑΠΤΥΞΗΣ, ΠΟΛΙΤΙΚΩΝ ΕΠΙΣΤΗΜΩΝ, ΔΙΟΙΚΗΣΗΣ ΕΠΙΧΕΙΡΗΣΕΩΝ (UID: 91738)
#    Κατηγορία: DEPARTMENT
# 3. Ονομασία: ΒΙΒΛΙΟΘΗΚΗ ΓΛΩΣΣΑΣ, ΦΙΛΟΛΟΓΙΑΣ ΚΑΙ ΠΟΛΙΤΙΣΜΟΥ ΠΑΡΕΥΞΕΙΩΝ ΧΩΡΩΝ (UID: 100058454)
#    Κατηγορία: DEPARTMENT
# 4. Ονομασία: ΒΙΒΛΙΟΘΗΚΗ Δ΄ ΙΑΤΡΙΚΗΣ, ΜΟΡ.ΒΙΟΛΟΓΙΑΣ & ΓΕΝΕΤΙΚΗΣ (UID: 93188)
#    Κατηγορία: DEPARTMENT
# 5. Ονομασία: ΒΙΒΛΙΟΘΗΚΗ ΕΠΙΣΤΗΜΩΝ ΥΓΕΙΑΣ (UID: 93190)
#    Κατηγορία: DEPARTMENT
# 6. Ονομασία: ΒΙΒΛΙΟΘΗΚΗ ΙΣΤΟΡΙΑΣ ΚΑΙ ΕΘΝΟΛΟΓΙΑΣ (UID: 100058453)
#    Κατηγορία: DEPARTMENT
# 7. Ονομασία: ΒΙΒΛΙΟΘΗΚΗ ΠΟΛΥΤΕΧΝΙΚΗΣ ΣΧΟΛΗΣ (UID: 93653)
#    Κατηγορία: DEPARTMENT
# 8. Ονομασία: ΒΙΒΛΙΟΘΗΚΗ ΣΧΟΛΗΣ ΕΠΙΣΤΗΜΩΝ ΑΓΩΓΗΣ (UID: 93562)
#    Κατηγορία: DEPARTMENT
# 9. Ονομασία: ΒΙΒΛΙΟΘΗΚΗ Τ.Ε.Φ.Α.Α. (UID: 93553)
#    Κατηγορία: UNIT
# 10. Ονομασία: ΒΙΒΛΙΟΘΗΚΗ ΤΩΝ ΤΜΗΜΑΤΩΝ ΔΑΣΟΛΟΓΙΑΣ ΚΑΙ ΑΓΡΟΤΙΚΗΣ ΑΝΑΠΤΥΞΗΣ ΤΟΥ Δ.Π.Θ. (UID: 93530)
#    Κατηγορία: DEPARTMENT
# 11. Ονομασία: ΓΡΑΜΜΑΤΕΙΑ ΠΡΥΤΑΝΗ (UID: 91641)
#    Κατηγορία: UNIT
# 12. Ονομασία: ΓΡΑΜΜΑΤΕΙΑ ΣΥΓΚΛΗΤΟΥ (UID: 85217)
#    Κατηγορία: UNIT
# 13. Ονομασία: ΓΡΑΜΜΑΤΕΙΑ ΣΥΜΒΟΥΛΙΟΥ ΔΙΟΙΚΗΣΗΣ (UID: 100078343)
#    Κατηγορία: DEPARTMENT
# 14. Ονομασία: ΓΡΑΦΕΙΟ ΚΙΝΗΣΗΣ (UID: 93066)
#    Κατηγορία: OFFICE
# 15. Ονομασία: ΔΙEΘΥΝΣΗ ΑΚΑΔΗΜΑΙΚΩΝ ΘΕΜΑΤΩΝ (UID: 86022)
#    Κατηγορία: ADMINISTRATION
# 16. Ονομασία: ΔΙΑΚΡΑΤΙΚΟ ΔΙΑΠΑΝΕΠΙΣΤΗΜΙΑΚΟ ΔΙΑΤΜΗΜΑΤΙΚΟ ΠΡΟΓΡΑΜΜΑ ΜΕΤΑΠΤΥΧΙΑΚΩΝ ΣΠΟΥΔΩΝ (UID: 100014332)
#    Κατηγορία: ORG_UNIT_OTHER
# 17. Ονομασία: ΔΙΑΤΜΗΜΑΤΙΚΟ ΠΡΟΓΡΑΜΜΑ ΜΕΤΑΠΤΥΧΙΑΚΩΝ ΣΠΟΥΔΩΝ AΣΚΗΣΗ ΚΑΙ ΠΟΙΟΤΗΤΑ ΖΩΗΣ (UID: 87720)
#    Κατηγορία: UNIT
# 18. Ονομασία: ΔΙΕΥΘΥΝΣΗ ΔΙΚΤΥΩΝ ΤΗΛΕΠΙΚΟΙΝΩΝΙΩΝ & ΥΠΟΛΟΓΙΣΤΙΚΩΝ ΥΠΟΔΟΜΩΝ (UID: 86623)
#    Κατηγορία: GENERAL_ADMINISTRATION
# 19. Ονομασία: ΔΙΕΥΘΥΝΣΗ ΔΙΟΙΚΗΤΙΚΟΥ (UID: 72317)
#    Κατηγορία: ADMINISTRATION
# 20. Ονομασία: ΔΙΕΥΘΥΝΣΗ ΔΙΟΙΚΗΤΙΚΩΝ ΥΠΟΘΕΣΕΩΝ ΚΑΙ ΦΟΙΤΗΤΙΚΗΣ ΜΕΡΙΜΝΑΣ ΚΑΒΑΛΑΣ-ΔΡΑΜΑΣ (UID: 100090686)
#    Κατηγορία: ADMINISTRATION
# 21. Ονομασία: ΔΙΕΥΘΥΝΣΗ ΜΗΧΑΝΟΡΓΑΝΩΣΗΣ (UID: 72315)
#    Κατηγορία: ADMINISTRATION
# 22. Ονομασία: ΔΙΕΥΘΥΝΣΗ ΟΙΚΟΝΟΜΙΚΗΣ ΔΙΑΧΕΙΡΗΣΗΣ (UID: 77377)
#    Κατηγορία: ADMINISTRATION
# 23. Ονομασία: ΔΙΕΥΘΥΝΣΗ ΤΕΧΝΙΚΩΝ ΕΡΓΩΝ (UID: 72314)
#    Κατηγορία: ADMINISTRATION
# 24. Ονομασία: ΔΙΙΔΡΥΜΑΤΙΚΟ ΠΡΟΓΡΑΜΜΑ ΜΕΤΑΠΤΥΧΙΑΚΩΝ ΣΠΟΥΔΩΝ ΚΛΙΝΙΚΗ ΑΣΚΗΣΗ ΚΑΙ ΕΦΑΡΜΟΓΕΣ ΤΗΣ ΤΕΧΝΟΛΟΓΙΑΣ ΣΤΗΝ ΥΓΕΙΑ (UID: 100093093)
#    Κατηγορία: ORG_UNIT_OTHER
# 25. Ονομασία: ΕΙΔΙΚΟΣ ΛΟΓΑΡΙΑΣΜΟΣ ΚΟΝΔΥΛΙΩΝ ΕΡΕΥΝΑΣ (UID: 75481)
#    Κατηγορία: UNIT
# 26. Ονομασία: ΕΚΤΕΛΕΣΤΙΚΟΥ ΔΙΕΥΘΥΝΤΗ (UID: 100080237)
#    Κατηγορία: ADMINISTRATION
# 27. Ονομασία: ΕΠΙΤΡΟΠΗ ΠΡΟΓΡΑΜΜΑΤΟΣ ΣΠΟΥΔΩΝ ΤΟΥ ΔΙΙΔΡΥΜΑΤΙΚΟΥ ΠΜΣ QUANTUM COMPUTING AND QUANTUM TECHNOLOGIES (UID: 100078004)
#    Κατηγορία: COMMITTEE
# 28. Ονομασία: ΕΠΙΤΡΟΠΗ ΠΡΟΓΡΑΜΜΑΤΟΣ ΣΠΟΥΔΩΝ ΤΟΥ ΔΠΜΣ BIOMEDICAL AND MOLECULAR SCIENCES-DIAGNOSIS AND TREATMENT OF HUMANDISEASES (UID: 100078011)
#    Κατηγορία: COMMITTEE
# 29. Ονομασία: ΕΠΙΤΡΟΠΗ ΠΡΟΓΡΑΜΜΑΤΟΣ ΣΠΟΥΔΩΝ ΤΟΥ ΔΠΜΣ TECHNOLOGICAL & MANAGEMENT ADVANCES ON INTELLIGENT TRANSPORTATION ELECTRIFICATION (UID: 100078005)
#    Κατηγορία: COMMITTEE
# 30. Ονομασία: ΕΠΙΤΡΟΠΗ ΠΡΟΓΡΑΜΜΑΤΟΣ ΣΠΟΥΔΩΝ ΤΟΥ ΔΠΜΣ ΑΡΧΑΙΑ ΕΛΛΗΝΙΚΗ ΓΡΑΦΗ: ΦΟΡΕΙΣ ΚΑΙ ΠΕΡΙΕΧΟΜΕΝΟ (UID: 100078009)
#    Κατηγορία: COMMITTEE
# 31. Ονομασία: ΕΠΙΤΡΟΠΗ ΠΡΟΓΡΑΜΜΑΤΟΣ ΣΠΟΥΔΩΝ ΤΟΥ ΔΠΜΣ ΒΙΟΙΑΤΡΙΚΕΣ ΚΑΙ ΜΟΡΙΑΚΕΣ ΕΠΙΣΤΗΜΕΣ ΣΤΗ ΔΙΑΓΝΩΣΗ ΚΑΙ ΘΕΡΑΠΕΙΑ ΑΣΘΕΝΕΙΩΝ (UID: 100078012)
#    Κατηγορία: COMMITTEE
# 32. Ονομασία: ΕΠΙΤΡΟΠΗ ΠΡΟΓΡΑΜΜΑΤΟΣ ΣΠΟΥΔΩΝ ΤΟΥ ΔΠΜΣ ΒΙΟΙΑΤΡΙΚΗ ΠΛΗΡΟΦΟΡΙΚΗ (UID: 100078013)
#    Κατηγορία: COMMITTEE
# 33. Ονομασία: ΕΠΙΤΡΟΠΗ ΠΡΟΓΡΑΜΜΑΤΟΣ ΣΠΟΥΔΩΝ ΤΟΥ ΔΠΜΣ ΕΞΕΙΔΙΚΕΥΣΗ ΣΤΙΣ Τ.Π.Ε. ΚΑΙ ΕΙΔΙΚΗ ΑΓΩΓΗ – ΨΥΧΟΠΑΙΔΑΓΩΓΙΚΗ ΤΗΣ ΕΝΤΑΞΗΣ (UID: 100077370)
#    Κατηγορία: COMMITTEE
# 34. Ονομασία: ΕΠΙΤΡΟΠΗ ΠΡΟΓΡΑΜΜΑΤΟΣ ΣΠΟΥΔΩΝ ΤΟΥ ΔΠΜΣ ΕΦΑΡΜΟΣΜΕΝΑ ΜΑΘΗΜΑΤΙΚΑ (UID: 100078006)
#    Κατηγορία: COMMITTEE
# 35. Ονομασία: ΕΠΙΤΡΟΠΗ ΠΡΟΓΡΑΜΜΑΤΟΣ ΣΠΟΥΔΩΝ ΤΟΥ ΔΠΜΣ ΚΛΙΝΙΚΗ ΑΣΚΗΣΗ ΚΑΙ ΕΦΑΡΜΟΓΕΣ ΤΗΣ ΤΕΧΝΟΛΟΓΙΑΣ ΣΤΗΝ ΥΓΕΙΑ (UID: 100078008)
#    Κατηγορία: COMMITTEE
# 36. Ονομασία: ΕΠΙΤΡΟΠΗ ΠΡΟΓΡΑΜΜΑΤΟΣ ΣΠΟΥΔΩΝ ΤΟΥ ΔΠΜΣ ΛΟΙΜΩΔΗ ΝΟΣΗΜΑΤΑ - ΔΙΕΘΝΗΣ ΙΑΤΡΙΚΗ ΑΠΟ ΤΟ ΕΡΓΑΣΤΗΡΙΟ ΣΤΗΝ ΚΛΙΝΙΚΗ ΠΡΑΞΗ (UID: 100078015)
#    Κατηγορία: COMMITTEE
# 37. Ονομασία: ΕΠΙΤΡΟΠΗ ΠΡΟΓΡΑΜΜΑΤΟΣ ΣΠΟΥΔΩΝ ΤΟΥ ΔΠΜΣ ΡΙΝΟΛΟΓΙΑ-ΡΙΝΟΧΕΙΡΟΥΡΓΙΚΗ (UID: 100078014)
#    Κατηγορία: COMMITTEE
# 38. Ονομασία: ΕΠΙΤΡΟΠΗ ΠΡΟΓΡΑΜΜΑΤΟΣ ΣΠΟΥΔΩΝ ΤΟΥ ΔΠΜΣ ΣΥΓΧΡΟΝΕΣ ΕΥΡΩΠΑΙΚΕΣ ΣΠΟΥΔΕΣ: ΔΙΚΑΙΟ ΟΙΚΟΝΟΜΙΑ ΠΟΛΙΤΙΚΗ (UID: 100078007)
#    Κατηγορία: COMMITTEE
# 39. Ονομασία: ΕΠΙΤΡΟΠΗ ΠΡΟΓΡΑΜΜΑΤΟΣ ΣΠΟΥΔΩΝ ΤΟΥ ΔΠΜΣ ΨΥΧΟΠΑΙΔΑΓΩΓΙΚΕΣ ΔΙΔΑΚΤΙΚΕΣ ΚΑΙ ΔΙΑΠΟΛΙΤΙΣΜΙΚΕΣ ΠΡΟΣΕΓΓΙΣΕΙΣ ΣΤΙΣ ΑΝΘΡΩΠΙΣΤΙΚΕΣ ΕΠΙΣΤΗΜΕΣ (UID: 100078010)
#    Κατηγορία: COMMITTEE
# 40. Ονομασία: ΕΡΓΟΘΕΡΑΠΕΙΑΣ (UID: 100093018)
#    Κατηγορία: DEPARTMENT
# 41. Ονομασία: ΚΕΝΤΡΙΚΗ ΒΙΒΛΙΟΘΗΚΗ Δ.Π.Θ. (UID: 91737)
#    Κατηγορία: ADMINISTRATION
# 42. Ονομασία: ΚΕΝΤΡΟ ΕΠΙΜΟΡΦΩΣΗΣ ΚΑΙ ΔΙΑ ΒΙΟΥ ΜΑΘΗΣΗΣ (UID: 100047294)
#    Κατηγορία: OFFICE
# 43. Ονομασία: ΛΕΙΤΟΥΡΓΙΚΟΣ ΚΛΙΝΙΚΟΕΡΓΑΣΤΗΡΙΑΚΟΣ ΤΟΜΕΑΣ (UID: 100022961)
#    Κατηγορία: SECTOR
# 44. Ονομασία: ΜΟΝΑΔΑ ΔΙΑΣΦΑΛΙΣΗΣ ΠΟΙΟΤΗΤΑΣ (UID: 100094223)
#    Κατηγορία: OFFICE
# 45. Ονομασία: ΜΟΝΑΔΑ ΕΣΩΤΕΡΙΚΟΥ ΕΛΕΓΧΟΥ (UID: 100090194)
#    Κατηγορία: UNIT
# 46. Ονομασία: ΜΟΝΑΔΑ ΟΙΚΟΝΟΜΙΚΗΣ ΚΑΙ ΔΙΟΙΚΗΤΙΚΗΣ ΥΠΟΣΤΗΡΙΞΗΣ (UID: 100080544)
#    Κατηγορία: UNIT
# 47. Ονομασία: ΜΟΡΦΟΛΟΓΙΚΟΣ ΚΛΙΝΙΚΟΕΡΓΑΣΤΗΡΙΑΚΟΣ ΤΟΜΕΑΣ (UID: 100022960)
#    Κατηγορία: SECTOR
# 48. Ονομασία: ΝΟΜΙΚΗ ΣΧΟΛΗ (UID: 94623)
#    Κατηγορία: UNIT
# 49. Ονομασία: ΝΟΜΙΚΗ ΥΠΗΡΕΣΙΑ (UID: 94085)
#    Κατηγορία: UNIT
# 50. Ονομασία: ΠΑΙΔΑΓΩΓΙΚΟ ΤΜΗΜΑ ΔΗΜΟΤΙΚΗΣ ΕΚΠΑΙΔΕΥΣΗΣ (Π.Τ.Δ.Ε.) (UID: 88360)
#    Κατηγορία: UNIT
# 51. Ονομασία: ΠΟΛΥΤΕΧΝΙΚΗ ΣΧΟΛΗ (UID: 94294)
#    Κατηγορία: UNIT
# 52. Ονομασία: ΣΥΜΒΟΥΛΙΟ ΔΙΟΙΚΗΣΗΣ (UID: 94823)
#    Κατηγορία: ORG_UNIT_OTHER
# 53. Ονομασία: ΣΥΝΤΟΝΙΣΤΙΚΗ ΕΠΙΤΡΟΠΗ ΤΟΥ ΔΠΜΣ ΕΞΕΙΔΙΚΕΥΣΗ ΣΤΙΣ Τ.Π.Ε. ΚΑΙ ΕΙΔΙΚΗ ΑΓΩΓΗ – ΨΥΧΟΠΑΙΔΑΓΩΓΙΚΗ ΤΗΣ ΕΝΤΑΞΗΣ (UID: 100077372)
#    Κατηγορία: COMMITTEE
# 54. Ονομασία: ΣΧΟΛΗ ΔΙΟΙΚΗΤΙΚΗΣ ΕΠΙΣΤΗΜΗΣ ΚΑΙ ΛΟΓΙΣΤΙΚΗΣ (UID: 100090126)
#    Κατηγορία: FACULTY
# 55. Ονομασία: ΣΧΟΛΗ ΕΠΙΣΤΗΜΗΣ ΦΥΣΙΚΗΣ ΑΓΩΓΗΣ ΚΑΙ ΑΘΛΗΤΙΣΜΟΥ (UID: 94662)
#    Κατηγορία: UNIT
# 56. Ονομασία: ΣΧΟΛΗ ΕΠΙΣΤΗΜΗΣ ΦΥΣΙΚΗΣ ΑΓΩΓΗΣ, ΑΘΛΗΤΙΣΜΟΥ ΚΑΙ ΕΡΓΟΘΕΡΑΠΕΙΑΣ (UID: 100092780)
#    Κατηγορία: FACULTY
# 57. Ονομασία: ΣΧΟΛΗ ΕΠΙΣΤΗΜΩΝ ΑΓΩΓΗΣ (UID: 88384)
#    Κατηγορία: UNIT
# 58. Ονομασία: ΣΧΟΛΗ ΕΠΙΣΤΗΜΩΝ ΓΕΩΠΟΝΙΑΣ ΚΑΙ ΔΑΣΟΛΟΓΙΑΣ (UID: 100006680)
#    Κατηγορία: FACULTY
# 59. Ονομασία: ΣΧΟΛΗ ΕΠΙΣΤΗΜΩΝ ΥΓΕΙΑΣ (UID: 94726)
#    Κατηγορία: UNIT
# 60. Ονομασία: ΣΧΟΛΗ ΘΕΤΙΚΩΝ ΕΠΙΣΤΗΜΩΝ (UID: 100090122)
#    Κατηγορία: FACULTY
# 61. Ονομασία: ΣΧΟΛΗ ΚΛΑΣΙΚΩΝ ΚΑΙ ΑΝΘΡΩΠΙΣΤΙΚΩΝ ΣΠΟΥΔΩΝ (UID: 95354)
#    Κατηγορία: UNIT
# 62. Ονομασία: ΣΧΟΛΗ ΚΟΙΝΩΝΙΚΩΝ ΠΟΛΙΤΙΚΩΝ ΚΑΙ ΟΙΚΟΝΟΜΙΚΩΝ ΕΠΙΣΤΗΜΩΝ (UID: 100016539)
#    Κατηγορία: FACULTY
# 63. Ονομασία: ΤΕΧΝΙΚΟ ΣΥΜΒΟΥΛΙΟ (UID: 100018313)
#    Κατηγορία: COMMITTEE
# 64. Ονομασία: ΤΜΗΜΑ  ΕΠΙΚΟΙΝΩΝΙΑΣ ΚΑΙ ΔΗΜΟΣΙΩΝ ΣΧΕΣΕΩΝ (UID: 93504)
#    Κατηγορία: DEPARTMENT
# 65. Ονομασία: ΤΜΗΜΑ ΑΓΡΟΤΙΚΗΣ ΑΝΑΠΤΥΞΗΣ (UID: 86453)
#    Κατηγορία: UNIT
# 66. Ονομασία: ΤΜΗΜΑ ΑΓΡΟΤΙΚΗΣ ΒΙΟΤΕΧΝΟΛΟΓΙΑΣ ΚΑΙ ΟΙΝΟΛΟΓΙΑΣ (UID: 100090332)
#    Κατηγορία: DEPARTMENT
# 67. Ονομασία: ΤΜΗΜΑ ΑΝΘΡΩΠΙΣΤΙΚΩΝ ΣΠΟΥΔΩΝ (UID: 100091638)
#    Κατηγορία: DEPARTMENT
# 68. Ονομασία: ΤΜΗΜΑ ΑΡΧΙΤΕΚΤΟΝΩΝ ΜΗΧΑΝΙΚΩΝ (UID: 87295)
#    Κατηγορία: UNIT
# 69. Ονομασία: ΤΜΗΜΑ ΓΕΝΙΚΟΥ ΠΡΩΤΟΚΟΛΛΟΥ-ΑΡΧΕΙΟΥ (UID: 100000166)
#    Κατηγορία: DEPARTMENT
# 70. Ονομασία: ΤΜΗΜΑ ΓΛΩΣΣΑΣ,ΦΙΛΟΛΟΓΙΑΣ ΚΑΙ ΠΟΛΙΤΙΣΜΟΥ ΠΑΡΕΥΞΕΙΝΙΩΝ ΧΩΡΩΝ (UID: 86692)
#    Κατηγορία: UNIT
# 71. Ονομασία: ΤΜΗΜΑ ΔΑΣΟΛΟΓΙΑΣ ΚΑΙ ΔΙΑΧΕΙΡΙΣΗΣ ΠΕΡΙΒΑΛΛΟΝΤΟΣ ΚΑΙ ΦΥΣΙΚΩΝ ΠΟΡΩΝ (UID: 86829)
#    Κατηγορία: UNIT
# 72. Ονομασία: ΤΜΗΜΑ ΔΑΣΟΛΟΓΙΑΣ ΚΑΙ ΦΥΣΙΚΟΥ ΠΕΡΙΒΑΛΛΟΝΤΟΣ (UID: 100090304)
#    Κατηγορία: DEPARTMENT
# 73. Ονομασία: ΤΜΗΜΑ ΔΙΕΘΝΩΝ ΟΙΚΟΝΟΜΙΚΩΝ ΣΧΕΣΕΩΝ ΚΑΙ ΑΝΑΠΤΥΞΗΣ (UID: 92983)
#    Κατηγορία: UNIT
# 74. Ονομασία: ΤΜΗΜΑ ΔΙΕΘΝΩΝ ΣΧΕΣΕΩΝ (UID: 93503)
#    Κατηγορία: DEPARTMENT
# 75. Ονομασία: ΤΜΗΜΑ ΔΙΟΙΚΗΣΗΣ ΕΠΙΧΕΙΡΗΣΕΩΝ (UID: 87669)
#    Κατηγορία: UNIT
# 76. Ονομασία: ΤΜΗΜΑ ΔΙΟΙΚΗΤΙΚΗΣ ΕΠΙΣΤΗΜΗΣ ΚΑΙ ΤΕΧΝΟΛΟΓΙΑΣ (UID: 100090127)
#    Κατηγορία: DEPARTMENT
# 77. Ονομασία: ΤΜΗΜΑ ΔΙΟΙΚΗΤΙΚΩΝ ΥΠΟΘΕΣΕΩΝ ΚΑΒΑΛΑΣ-ΔΡΑΜΑΣ (UID: 100097375)
#    Κατηγορία: DEPARTMENT
# 78. Ονομασία: ΤΜΗΜΑ ΕΚΤΕΛΕΣΗΣ ΕΡΓΩΝ Δ.Τ.Ε. (UID: 94959)
#    Κατηγορία: DEPARTMENT
# 79. Ονομασία: ΤΜΗΜΑ ΕΛΛΗΝΙΚΗΣ ΦΙΛΟΛΟΓΙΑΣ (UID: 87287)
#    Κατηγορία: UNIT
# 80. Ονομασία: ΤΜΗΜΑ ΕΠΙΚΟΙΝΩΝΙΩΝ (UID: 100081455)
#    Κατηγορία: DEPARTMENT
# 81. Ονομασία: ΤΜΗΜΑ ΕΠΙΣΤΗΜΗΣ ΦΥΣΙΚΗΣ ΑΓΩΓΗΣ ΚΑΙ ΑΘΛΗΤΙΣΜΟΥ (UID: 85894)
#    Κατηγορία: UNIT
# 82. Ονομασία: ΤΜΗΜΑ ΕΠΙΣΤΗΜΩΝ ΤΗΣ ΕΚΠΑΙΔΕΥΣΗΣ ΣΤΗΝ ΠΡΟΣΧΟΛΙΚΗ ΗΛΙΚΙΑ (UID: 87057)
#    Κατηγορία: UNIT
# 83. Ονομασία: ΤΜΗΜΑ ΗΛΕΚΤΡΟΛΟΓΩΝ ΜΗΧΑΝΙΚΩΝ ΚΑΙ ΜΗΧΑΝΙΚΩΝ ΥΠΟΛΟΓΙΣΤΩΝ (UID: 77667)
#    Κατηγορία: UNIT
# 84. Ονομασία: ΤΜΗΜΑ ΙΑΤΡΙΚΗΣ (UID: 77905)
#    Κατηγορία: UNIT
# 85. Ονομασία: ΤΜΗΜΑ ΙΣΤΟΡΙΑΣ ΚΑΙ ΕΘΝΟΛΟΓΙΑΣ (UID: 86628)
#    Κατηγορία: UNIT
# 86. Ονομασία: ΤΜΗΜΑ ΚΟΙΝΩΝΙΚΗΣ ΔΙΟΙΚΗΣΗΣ (UID: 87864)
#    Κατηγορία: UNIT
# 87. Ονομασία: ΤΜΗΜΑ ΚΟΙΝΩΝΙΚΗΣ ΔΙΟΙΚΗΣΗΣ ΚΑΙ ΠΟΛΙΤΙΚΗΣ ΕΠΙΣΤΗΜΗΣ (UID: 94281)
#    Κατηγορία: DEPARTMENT
# 88. Ονομασία: ΤΜΗΜΑ ΚΟΙΝΩΝΙΚΗΣ ΕΡΓΑΣΙΑΣ (UID: 100048426)
#    Κατηγορία: UNIT
# 89. Ονομασία: ΤΜΗΜΑ ΚΟΙΝΩΝΙΚΗΣ ΠΟΛΙΤΙΚΗΣ (UID: 100048428)
#    Κατηγορία: UNIT
# 90. Ονομασία: ΤΜΗΜΑ ΛΟΓΙΣΤΙΚΗΣ ΚΑΙ ΧΡΗΜΑΤΟΟΙΚΟΝΟΜΙΚΗΣ (UID: 100090128)
#    Κατηγορία: DEPARTMENT
# 91. Ονομασία: ΤΜΗΜΑ ΜΕΛΕΤΩΝ Δ.Τ.Ε (UID: 94958)
#    Κατηγορία: DEPARTMENT
# 92. Ονομασία: ΤΜΗΜΑ ΜΗΧΑΝΙΚΩΝ ΠΑΡΑΓΩΓΗΣ ΚΑΙ ΔΙΟΙΚΗΣΗΣ (UID: 87225)
#    Κατηγορία: UNIT
# 93. Ονομασία: ΤΜΗΜΑ ΜΗΧΑΝΙΚΩΝ ΠΕΡΙΒΑΛΛΟΝΤΟΣ (UID: 89130)
#    Κατηγορία: UNIT
# 94. Ονομασία: ΤΜΗΜΑ ΜΟΡΙΑΚΗΣ ΒΙΟΛΟΓΙΑΣ ΚΑΙ ΓΕΝΕΤΙΚΗΣ (UID: 84060)
#    Κατηγορία: UNIT
# 95. Ονομασία: ΤΜΗΜΑ ΝΟΜΙΚΗΣ (UID: 78291)
#    Κατηγορία: UNIT
# 96. Ονομασία: ΤΜΗΜΑ ΝΟΣΗΛΕΥΤΙΚΗΣ (UID: 100090129)
#    Κατηγορία: DEPARTMENT
# 97. Ονομασία: ΤΜΗΜΑ ΟΙΚΟΝΟΜΙΚΗΣ ΔΙΑΧΕΙΡΙΣΗΣ ΑΛΕΞΑΝΔΡΟΥΠΟΛΗΣ (UID: 92780)
#    Κατηγορία: DEPARTMENT
# 98. Ονομασία: ΤΜΗΜΑ ΟΙΚΟΝΟΜΙΚΗΣ ΔΙΑΧΕΙΡΙΣΗΣ ΞΑΝΘΗΣ (UID: 91740)
#    Κατηγορία: DEPARTMENT
# 99. Ονομασία: ΤΜΗΜΑ ΟΙΚΟΝΟΜΙΚΩΝ ΕΠΙΣΤΗΜΩΝ (UID: 94006)
#    Κατηγορία: DEPARTMENT
# 100. Ονομασία: ΤΜΗΜΑ ΠΛΗΡΟΦΟΡΙΚΗΣ (UID: 100090123)
#    Κατηγορία: DEPARTMENT
# 101. Ονομασία: ΤΜΗΜΑ ΠΟΛΙΤΙΚΗΣ ΕΠΙΣΤΗΜΗΣ (UID: 100048427)
#    Κατηγορία: UNIT
# 102. Ονομασία: ΤΜΗΜΑ ΠΟΛΙΤΙΚΩΝ ΕΠΙΣΤΗΜΩΝ (UID: 88322)
#    Κατηγορία: UNIT
# 103. Ονομασία: ΤΜΗΜΑ ΠΟΛΙΤΙΚΩΝ ΜΗΧΑΝΙΚΩΝ (UID: 87217)
#    Κατηγορία: UNIT
# 104. Ονομασία: ΤΜΗΜΑ ΠΡΟΜΗΘΕΙΩΝ (UID: 72316)
#    Κατηγορία: DEPARTMENT
# 105. Ονομασία: ΤΜΗΜΑ ΤΕΧΝΙΚΩΝ ΕΡΓΩΝ ΑΛΕΞΑΝΔΡΟΥΠΟΛΗΣ Δ.Τ.Ε. (UID: 94961)
#    Κατηγορία: DEPARTMENT
# 106. Ονομασία: ΤΜΗΜΑ ΤΕΧΝΙΚΩΝ ΕΡΓΩΝ ΞΑΝΘΗΣ Δ.Τ.Ε. (UID: 94960)
#    Κατηγορία: DEPARTMENT
# 107. Ονομασία: ΤΜΗΜΑ ΥΠΟΣΤΗΡΙΞΗΣ ΠΡΟΜΗΘΕΙΩΝ, ΔΙΑΓΩΝΙΣΜΩΝ ΚΑΙ ΠΕΡΙΟΥΣΙΑΣ ΚΑΒΑΛΑΣ-ΔΡΑΜΑΣ (UID: 100092068)
#    Κατηγορία: DEPARTMENT
# 108. Ονομασία: ΤΜΗΜΑ ΦΥΣΙΚΗΣ (UID: 100090125)
#    Κατηγορία: DEPARTMENT
# 109. Ονομασία: ΤΜΗΜΑ ΧΗΜΕΙΑΣ (UID: 100090124)
#    Κατηγορία: DEPARTMENT
# 110. Ονομασία: ΤΜΗΜΑ ΨΥΧΟΛΟΓΙΑΣ (UID: 100080801)
#    Κατηγορία: UNIT
# 111. Ονομασία: ΤΟΜΕΑΣ ΑΡΧΙΤΕΚΤΟΝΙΚΩΝ ΣΥΝΘΕΣΕΩΝ ΟΙΚΟΔΟΜΙΚΗΣ ΚΑΙ ΔΟΜΙΚΩΝ ΥΛΙΚΩΝ (UID: 100016872)
#    Κατηγορία: SECTOR
# 112. Ονομασία: ΤΟΜΕΑΣ ΓΕΝΙΚΗΣ ΠΑΘΟΛΟΓΙΑΣ (UID: 100022962)
#    Κατηγορία: SECTOR
# 113. Ονομασία: ΤΟΜΕΑΣ ΓΕΩΤΕΧΝΙΚΗΣ ΜΗΧΑΝΙΚΗΣ (UID: 100016865)
#    Κατηγορία: SECTOR
# 114. Ονομασία: ΤΟΜΕΑΣ ΔΗΜΟΣΙΟΥ ΔΙΚΑΙΟΥ ΚΑΙ ΠΟΛΙΤΙΚΗΣ ΕΠΙΣΤΗΜΗΣ (UID: 100016495)
#    Κατηγορία: SECTOR
# 115. Ονομασία: ΤΟΜΕΑΣ ΔΙΕΘΝΩΝ ΣΠΟΥΔΩΝ (UID: 100016493)
#    Κατηγορία: SECTOR
# 116. Ονομασία: ΤΟΜΕΑΣ ΔΙΚΑΙΟΥ ΤΩΝ ΕΠΙΧΕΙΡΗΣΕΩΝ ΚΑΙ ΕΡΓΑΣΙΑΚΟΥ ΔΙΚΑΙΟΥ (UID: 100016536)
#    Κατηγορία: SECTOR
# 117. Ονομασία: ΤΟΜΕΑΣ ΔΟΜΙΚΩΝ ΚΑΤΑΣΚΕΥΩΝ (UID: 100016859)
#    Κατηγορία: SECTOR
# 118. Ονομασία: ΤΟΜΕΑΣ ΕΝΕΡΓΕΙΑΚΩΝ ΣΥΣΤΗΜΑΤΩΝ (UID: 100016724)
#    Κατηγορία: SECTOR
# 119. Ονομασία: ΤΟΜΕΑΣ ΕΣΩΤΕΡΙΚΗΣ ΠΑΘΟΛΟΓΙΑΣ (UID: 100022963)
#    Κατηγορία: SECTOR
# 120. Ονομασία: ΤΟΜΕΑΣ ΗΛΕΚΤΡΟΝΙΚΗΣ ΚΑΙ ΤΕΧΝΟΛΟΓΙΑΣ ΣΥΣΤΗΜΑΤΩΝ ΠΛΗΡΟΦΟΡΙΚΗΣ (UID: 100016725)
#    Κατηγορία: SECTOR
# 121. Ονομασία: ΤΟΜΕΑΣ ΙΔΙΩΤΙΚΟΥ ΔΙΚΑΙΟΥ (UID: 100016496)
#    Κατηγορία: SECTOR
# 122. Ονομασία: ΤΟΜΕΑΣ ΛΟΓΙΣΜΙΚΟΥ ΚΑΙ ΑΝΑΠΤΥΞΗΣ ΕΦΑΡΜΟΓΩΝ (UID: 100016726)
#    Κατηγορία: SECTOR
# 123. Ονομασία: ΤΟΜΕΑΣ ΜΑΘΗΜΑΤΙΚΩΝ, ΠΡΟΓΡΑΜΜΑΤΙΣΜΟΥ ΚΑΙ ΓΕΝΙΚΩΝ ΜΑΘΗΜΑΤΩΝ (UID: 100016861)
#    Κατηγορία: SECTOR
# 124. Ονομασία: ΤΟΜΕΑΣ ΜΗΧΑΝΙΚΗΣ (UID: 100016863)
#    Κατηγορία: SECTOR
# 125. Ονομασία: ΤΟΜΕΑΣ ΝΕΥΡΙΚΟΥ ΣΥΣΤΗΜΑΤΟΣ & ΑΙΣΘΗΤΗΡΙΩΝ ΟΡΓΑΝΩΝ (UID: 100022967)
#    Κατηγορία: SECTOR
# 126. Ονομασία: ΤΟΜΕΑΣ ΠΟΙΝΙΚΩΝ ΚΑΙ ΕΓΛΚΗΜΑΤΟΛΟΓΙΚΩΝ ΕΠΙΣΤΗΜΩΝ (UID: 100016491)
#    Κατηγορία: SECTOR
# 127. Ονομασία: ΤΟΜΕΑΣ ΣΥΓΚΟΙΝΩΝΙΑΚΩΝ ΕΡΓΩΝ ΚΑΙ ΜΕΤΑΦΟΡΩΝ (UID: 100016867)
#    Κατηγορία: SECTOR
# 128. Ονομασία: ΤΟΜΕΑΣ ΤΗΛΕΠΙΚΟΙΝΩΝΙΩΝ ΚΑΙ ΔΙΑΣΤΗΜΙΚΗΣ (UID: 100016727)
#    Κατηγορία: SECTOR
# 129. Ονομασία: ΤΟΜΕΑΣ ΥΓΕΙΑΣ ΠΑΙΔΙΟΥ (UID: 100022966)
#    Κατηγορία: SECTOR
# 130. Ονομασία: ΤΟΜΕΑΣ ΥΔΡΑΥΛΙΚΩΝ ΕΡΓΩΝ (UID: 100016870)
#    Κατηγορία: SECTOR
# 131. Ονομασία: ΤΟΜΕΑΣ ΨΥΧΙΑΤΡΙΚΗΣ (UID: 100022968)
#    Κατηγορία: SECTOR
# 132. Ονομασία: ΥΓΕΙΑΣ ΠΑΙΔΙΟΥ (UID: 100036757)
#    Κατηγορία: SECTOR
# 133. Ονομασία: ΧΕΙΡΟΥΡΓΙΚΟΣ ΤΟΜΕΑΣ (UID: 100022965)
#    Κατηγορία: SECTOR
